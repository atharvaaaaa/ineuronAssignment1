# %% [markdown]
# # 1.What are the two values of the Boolean data type? How do you write them?
# Ans: Boolean datatype can have two values Either true or false

# %% [markdown]
# # 2. What are the three different types of Boolean operators?
# Ans: The three different types of Boolean operators are AND, OR and NOT

# %% [markdown]
# # 3. Make a list of each Boolean operator's truth tables (i.e. every possible combination of Boolean values for the operator and what it evaluate ).
#
# Ans:
#
# And:
#
# TRUE AND TRUE = TRUE
#
# TRUE AND FALSE = FALSE
#
# FALSE AND TRUE = FALSE
#
# FALSE AND FALSE = FALSE
#
# OR:
#
# TRUE OR TRUE = TRUE
#
# TRUE OR FALSE = TRUE
#
# FALSE OR TRUE = TRUE
#
# FALSE OR FALSE = FALSE
#
# NOT:
#
# NOT TRUE = FALSE
#
# NOT FALSE = TRUE
#
# NOT TRUE AND NOT FALSE = FALSE
#
# NOT FALSE AND NOT TRUE = FALSE
#
# NOT FALSE AND NOT FALSE = TRUE
#
# NOT TRUE AND NOT TRUE = FALSE
#
# NOT TRUE OR NOT TRUE = FALSE
#
# NOT TRUE OR NOT FALSE = TRUE
#
# NOT FALSE OR NOT TRUE = TRUE
#
# NOT FALSE OR NOT FALSE = TRUE

# %% [markdown]
# # 4. What are the values of the following expressions?
#
# (5 > 4) and (3 == 5)
#
# not (5 > 4)
#
# (5 > 4) or (3 == 5)
#
# not ((5 > 4) or (3 == 5))
#
# (True and True) and (True == False)
#
# (not False) or (not True)
#
# Ans:
#
# -> (5 > 4) and (3 == 5) is False
#
# -> not (5>4) is False
#
# -> (5 > 4) or (3 == 5) is True
#
# -> not ((5 > 4) or (3 == 5)) is False
#
# -> (True and True) and (True == False) is False
#
# -> (not False) or (not True) is True

# %% [markdown]
# # 5. What are the six comparison operators?
# Ans: The six comparison operators are
#
# Less than ( < )
#
# Less than or equal to ( <= )
#
# Greater than ( > )
#
# Greater than or equal to ( >= )
#
# Equal to ( == )
#
# Not equal to ( != )

# %% [markdown]
# # 6. How do you tell the difference between the equal to and assignment operators?Describe a condition and when you would use one.
# Ans:
#
# Equal to operator is a comparison operator, where assignment operator assigns a paricular value to a variable
#
# for ex:
#
# A = 6 here assignment operator is used to show value 6 is assigned to the variable A
#
# A == 6 here Equal to operator is used which returns a boolean value (True/False in this case True) to check if the value 6 is really assigned to the variable A

# %% [markdown]
# # 7. Identify the three blocks in this code:
#
# spam = 0
#
# if spam == 10:
#
# print('eggs')
#
# if spam > 5:
#
# print('bacon')
#
# else:
#
# print('ham')
#
# print('spam')
#
# print('spam')
#
#
# Ans:
#
# The three blocks of this code are
#
# print('eggs')
#
# if spam > 5:
#
#     print('bacon')
#
# else:
#
#     print('ham')
#
# print('spam')

# %% [markdown]
# # 8. Write code that prints Hello if 1 is stored in spam, prints Howdy if 2 is stored in spam, and prints Greetings! if anything else is stored in spam.
#
# Ans:
#
# spam = int(input(""))
#
# if(spam==1):
#
#     print("Hello")
#
# elif(spam==2):
#
#     print("Howdy")
#
# else:
#
#     print("Greetings!")

# %% [markdown]
# # 9.If your programme is stuck in an endless loop, what keys you’ll press?
# Ans: Ctrl+C

# %% [markdown]
# # 10. How can you tell the difference between break and continue?
# Ans: Break and Continue statements are used in loops
#
# Break: We use Break in the loop to stop the loop when the given conditions are met
#
# ex:
#
# a = 1
#
# for(a<=5):
#
#     print(a)
#
#
#     if(a==3):
#
#         break
#     a=a+1
#
#
# Output:
#
# 1
# 2
# 3
#
# Continue:
# We use Break in the loop to end the iteration when given conditions are met and continue to next iteration
#
# ex:
#
# a = 1
#
# for(a<=5):
#
#     print(a)
#
#
#     if(a==3):
#
#         Continue
#     a=a+1
#
# Output:
#
# 1
# 2
# 4
# 5

# %% [markdown]
# # 11. In a for loop, what is the difference between range(10), range(0, 10), and range(0, 10, 1)?
# Ans:
# range(10): This will create a sequence of numbers from 0 to 9
#
# range(0,10): This will create a sequence of numbers from 0 to 9
#
# range(0,10,1): This will create a sequence of numbers from 0 to 9 with increment of 1
#
# There is no difference in output

# %% [markdown]
# # 12. Write a short program that prints the numbers 1 to 10 using a for loop. Then write an equivalent program that prints the numbers 1 to 10 using a while loop.
# Ans:
# 1. Short program to print n using For loop
# ->
# for x in range(1,11):
#
#     print(x, end=" ")
#
# 2. Using While loop
# ->
# x= 1
#
# while(x<=10):
#
#     print(x)
#
#     x=x+1

# %% [markdown]
# # 13. If you had a function named bacon() inside a module named spam, how would you call it after importing spam?
# Ans: The function can be called using spam.bacon()
